# %% [markdown]
# # VARIABLES IN PYTHON

# %%
# Creating Variables

a = 10
name = "Krushna"
price = 99.5

print(a)
print(name)
print(price)
# Out:
# 10
# Krushna
# 99.5

# %%
# Rules for Variable Names

# Valid
age = 20
student_name = "Ram"

# Invalid
# 1age = 20
# student-name = "Ram"

# %%
# Multiple Variable Assignment

x, y, z = 1, 2, 3

print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
# Practice Question 1
# Create a variable storing your age

age = 21

print(age)
# Out:
# 21

# %%
# Practice Question 2
# Create variables for name and city

name = "Krushna"
city = "Hyderabad"

print(name)
print(city)
# Out:
# Krushna
# Hyderabad

# %%
# Practice Question 3
# Print all variables

age = 21
name = "Krushna"
city = "Hyderabad"

print(age)
print(name)
print(city)
# Out:
# 21
# Krushna
# Hyderabad
